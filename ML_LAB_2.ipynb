# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandini-0905/ML-LAB/blob/main/ML_LAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
num = 9
angle_degrees = 45

# %%
print("Square Root:", math.sqrt(num))
print("Factorial:", math.factorial(5))
print("Logarithm base 10:", math.log10(100))
print("Sine of 45 degrees:", math.sin(math.radians(angle_degrees)))
print("Value of Pi:", math.pi)
# Out:
# Square Root: 3.0
# Factorial: 120
# Logarithm base 10: 2.0
# Sine of 45 degrees: 0.7071067811865475
# Value of Pi: 3.141592653589793

# %%
import math

# %%
num1 = 4.3
num2 = 9.7
num3 = -2.8
num4 = 5.0

# %%
print("Ceil of", num1, "is:", math.ceil(num1))  # Output: 5
print("Ceil of", num2, "is:", math.ceil(num2))  # Output: 10
print("Ceil of", num3, "is:", math.ceil(num3))  # Output: -2
print("Ceil of", num4, "is:", math.ceil(num4))  # Output: 5 (unchanged)
# Out:
# Ceil of 4.3 is: 5
# Ceil of 9.7 is: 10
# Ceil of -2.8 is: -2
# Ceil of 5.0 is: 5

# %%
import numpy as np

# %%
a = np.array([1, 2, 3])   # Create a rank 1 array
print(type(a))
print(a.shape)            # Prints "(3,)"
print(a[0], a[1], a[2])   # Prints "1 2 3"
a[0] = 5                  # Change an element of the array
print(a)                  # Prints "[5, 2, 3]"
b = np.array([[1,2,3],[4,5,6]])    # Create a rank 2 array
print(b.shape)                     # Prints "(2, 3)"
print(b[0, 0], b[0, 1], b[1, 0])   # Prints "1 2 4"
# Out:
# <class 'numpy.ndarray'>
# (3,)
# 1 2 3
# [5 2 3]
# (2, 3)
# 1 2 4
